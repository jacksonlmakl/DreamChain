# %%
from dreamchain import DreamChainNode

# Create and connect Node 1
node1 = DreamChainNode(5010)
# Out:
# Received nodes from master: [('localhost', 5001)]
# Registered with node ('localhost', 5001)
# Current registered nodes: {('localhost', 5001)}
# Registered with node ('54.197.152.22', 5000)
# Current registered nodes: {('54.197.152.22', 5000), ('localhost', 5001)}
# Chain replaced with the longest one from peer.
# Chain replaced with the longest one.
# Resolving conflicts to sync with the master node's chain...
# Our chain is authoritative.

# %%
# Node 1 mines a block
node1.add_transaction('Test', 'Test', {'Data':'Some Data Here'})
node1.mine_block()

# %%
node1.get_chain()
# Out:
# Resolving conflicts to sync with the latest chain from peers...
# Error fetching chain from peer ('54.197.152.22', 5000): [Errno 61] Connection refused
# Our chain is authoritative.
# [{'index': 1,
#   'timestamp': 1726004287.082536,
#   'transactions': [],
#   'proof': 100,
#   'previous_hash': '1'},
#  {'index': 2,
#   'timestamp': 1726004293.369629,
#   'transactions': [{'sender': 'Jackson',
#     'recipient': 'Jackson',
#     'data': {'Data': 'Something'}}],
#   'proof': 35293,
#   'previous_hash': '4bd0c0663dda7dc8106543842da864c799f37649b35252174860724970e0c110'},
#  {'index': 3,
#   'timestamp': 1726004296.3841212,
#   'transactions': [{'sender': 'Jackson',
#     'recipient': 'Jackson',
#     'data': {'Data': 'Something'}}],
#   'proof': 35089,
#   'previous_hash': '9ba9e9786e874cfb7b5d9368c7f3574b4ad60befb7ff347ee40418d2bfc4e6c9'},
#  {'index': 4,
#   'timestamp': 1726004296.8679209,
#   'transactions': [{'sender': 'Jackson',
#     'recipient': 'Jackson',
#     'data': {'Data': 'Something'}}],
#   'proof': 119678,
#   'previous_hash': 'fcee7c45bea1b7c4c6f2fb4b78968811e54f32892eaf8767aaff4184d09305fc'},
#  {'index': 5,
#   'timestamp': 1726004297.364224,
#   'transactions': [{'sender': 'Jackson',
#     'recipient': 'Jackson',
#     'data': {'Data': 'Something'}}],
#   'proof': 146502,
#   'previous_hash': '07c33d29bfa0abb25a8c9b7cde46dde9eb3ddf2fae6b4b33c8c8b65aad980c86'},
#  {'index': 6,
#   'timestamp': 1726004297.627328,
#   'transactions': [{'sender': 'Jackson',
#     'recipient': 'Jackson',
#     'data': {'Data': 'Something'}}],
#   'proof': 43538,
#   'previous_hash': 'e6cb8d06e1fd805b268565de4ff5cb04a871f4175a628a0c917afb7412914861'},
#  {'index': 7,
#   'timestamp': 1726004298.064505,
#   'transactions': [{'sender': 'Jackson',
#     'recipient': 'Jackson',
#     'data': {'Data': 'Something'}}],
#   'proof': 85724,
#   'previous_hash': '5ef0a64ada282a422326b740aedea4768f99ce85fbf8f632be63b04a75c95e56'},
#  {'index': 8,
#   'timestamp': 1726004298.4291189,
#   'transactions': [{'sender': 'Jackson',
#     'recipient': 'Jackson',
#     'data': {'Data': 'Something'}}],
#   'proof': 51178,
#   'previous_hash': '39a13c49935d00f56e3bcb08714351ee7db88172c39ddb1ee692296631a27e82'},
#  {'index': 9,
#   'timestamp': 1726004298.904263,
#   'transactions': [{'sender': 'Jackson',
#     'recipient': 'Jackson',
#     'data': {'Data': 'Something'}}],
#   'proof': 71730,
#   'previous_hash': 'acc5c8cd3ff98ad82426fdd3f7eedb3dc471a9533ea9bc85d3c78b8351f7cbd3'},
#  {'index': 10,
#   'timestamp': 1726004299.3375301,
#   'transactions': [{'sender': 'Jackson',
#     'recipient': 'Jackson',
#     'data': {'Data': 'Something'}}],
#   'proof': 55589,
#   'previous_hash': '11c215b2444b63b117ce622e86560506bff467720fce61b04858ba8a802fd8ba'},
#  {'index': 11,
#   'timestamp': 1726004299.736067,
#   'transactions': [{'sender': 'Jackson',
#     'recipient': 'Jackson',
#     'data': {'Data': 'Something'}}],
#   'proof': 35704,
#   'previous_hash': '3af542b01c354ce560fc320655ba2bf3e1272ac0b8044981f2d52faa5801c016'},
#  {'index': 12,
#   'timestamp': 1726004301.801408,
#   'transactions': [{'sender': 'Jackson',
#     'recipient': 'Jackson',
#     'data': {'Data': 'Something'}}],
#   'proof': 57342,
#   'previous_hash': 'a98cdf2ff361110ee6f40c7ac72a73244382628716bf3375e0608c2d2f6e64ca'},
#  {'index': 13,
#   'timestamp': 1726004331.1155999,
#   'transactions': [{'sender': 'Test',
#     'recipient': 'Test',
#     'data': {'Data': 'Some Data Here'}}],
#   'proof': 68975,
#   'previous_hash': 'bb95df0edd6d4a3fec5840414a75bc31b05956ceab4c6208f356f35e23bbf0ef'},
#  {'index': 14,
#   'timestamp': 1726004344.111656,
#   'transactions': [{'sender': 'Test',
#     'recipient': 'Test',
#     'data': {'Data': 'Some Data Here'}}],
#   'proof': 153122,
#   'previous_hash': '760dda6a5e34c389a492b3259c3cb1d2cd6551f2b9f983505893950f1026d1db'},
#  {'index': 15,
#   'timestamp': 1726004344.641976,
#   'transactions': [{'sender': 'Test',
#     'recipient': 'Test',
#     'data': {'Data': 'Some Data Here'}}],
#   'proof': 20760,
#   'previous_hash': '11d78e62bea51d3df3aa6bb91a385ffc09edeae5785ef1c95a207761cf01d116'},
#  {'index': 16,
#   'timestamp': 1726004345.141493,
#   'transactions': [{'sender': 'Test',
#     'recipient': 'Test',
#     'data': {'Data': 'Some Data Here'}}],
#   'proof': 29341,
#   'previous_hash': '93900629ca863e79ef9302b161d589539ecadab7828c3df8a8386f586027d8db'},
#  {'index': 17,
#   'timestamp': 1726004345.592936,
#   'transactions': [{'sender': 'Test',
#     'recipient': 'Test',
#     'data': {'Data': 'Some Data Here'}}],
#   'proof': 15889,
#   'previous_hash': 'c26bef43337d6a574ed3ead289d294eefa8c447d3420227ef44374fe74715593'},
#  {'index': 18,
#   'timestamp': 1726004346.209978,
#   'transactions': [{'sender': 'Test',
#     'recipient': 'Test',
#     'data': {'Data': 'Some Data Here'}}],
#   'proof': 209765,
#   'previous_hash': 'febd3b575003e24d7eaab659c4e6d5c57b6ca66f818c0fe36671ae6a37191855'},
#  {'index': 19,
#   'timestamp': 1726004346.53492,
#   'transactions': [{'sender': 'Test',
#     'recipient': 'Test',
#     'data': {'Data': 'Some Data Here'}}],
#   'proof': 3748,
#   'previous_hash': 'ac685d3a4f6c3ff6ee9c0c076e3d7ba5b45c9c3037c4cfde5f41ff33e7b687f5'},
#  {'index': 20,
#   'timestamp': 1726004347.085098,
#   'transactions': [{'sender': 'Test',
#     'recipient': 'Test',
#     'data': {'Data': 'Some Data Here'}}],
#   'proof': 28807,
#   'previous_hash': 'cfc83100de3aa233cc059bf90f0844ebad80be6923e83f14846dd5a790e47c2a'},
#  {'index': 21,
#   'timestamp': 1726004347.5483232,
#   'transactions': [{'sender': 'Test',
#     'recipient': 'Test',
#     'data': {'Data': 'Some Data Here'}}],
#   'proof': 70832,
#   'previous_hash': '0c8294875dc17751a04bfd0d9ad6f3a4d14e256c31856de7db26bca9f8ef527b'},
#  {'index': 22,
#   'timestamp': 1726004347.996439,
#   'transactions': [{'sender': 'Test',
#     'recipient': 'Test',
#     'data': {'Data': 'Some Data Here'}}],
#   'proof': 47031,
#   'previous_hash': 'f3b5b60c19b89fe7af507f2ac6f2c1626109496e24e7204990e0a7a583beb18a'},
#  {'index': 23,
#   'timestamp': 1726004348.443152,
#   'transactions': [{'sender': 'Test',
#     'recipient': 'Test',
#     'data': {'Data': 'Some Data Here'}}],
#   'proof': 48098,
#   'previous_hash': '8b5df6ae8a996e194c8037f5f238cbfe027e36bd8783e0a38736c86ccf8e7778'},
#  {'index': 24,
#   'timestamp': 1726004348.830003,
#   'transactions': [{'sender': 'Test',
#     'recipient': 'Test',
#     'data': {'Data': 'Some Data Here'}}],
#   'proof': 30743,
#   'previous_hash': 'ebbb8cd21211199d965a4fc688a324357f79044acece84636a6d5c26a3620368'},
#  {'index': 25,
#   'timestamp': 1726004349.2234602,
#   'transactions': [{'sender': 'Test',
#     'recipient': 'Test',
#     'data': {'Data': 'Some Data Here'}}],
#   'proof': 41003,
#   'previous_hash': '8df6085e464553881c9451ac96d362f3cb45c79671f67e197dfc629fc0c42094'},
#  {'index': 26,
#   'timestamp': 1726004349.954637,
#   'transactions': [{'sender': 'Test',
#     'recipient': 'Test',
#     'data': {'Data': 'Some Data Here'}}],
#   'proof': 89991,
#   'previous_hash': 'ea47ba94cf933ace0ef4b9be7ded570c63e0ee937bb3fcc7e45eb9199f117470'}]

# %%
node1.get_chain()
# Out:
# Resolving conflicts to sync with the latest chain from peers...
# Our chain is authoritative.
# [{'index': 1,
#   'timestamp': 1726004287.082536,
#   'transactions': [],
#   'proof': 100,
#   'previous_hash': '1'},
#  {'index': 2,
#   'timestamp': 1726004293.369629,
#   'transactions': [{'sender': 'Jackson',
#     'recipient': 'Jackson',
#     'data': {'Data': 'Something'}}],
#   'proof': 35293,
#   'previous_hash': '4bd0c0663dda7dc8106543842da864c799f37649b35252174860724970e0c110'},
#  {'index': 3,
#   'timestamp': 1726004296.3841212,
#   'transactions': [{'sender': 'Jackson',
#     'recipient': 'Jackson',
#     'data': {'Data': 'Something'}}],
#   'proof': 35089,
#   'previous_hash': '9ba9e9786e874cfb7b5d9368c7f3574b4ad60befb7ff347ee40418d2bfc4e6c9'},
#  {'index': 4,
#   'timestamp': 1726004296.8679209,
#   'transactions': [{'sender': 'Jackson',
#     'recipient': 'Jackson',
#     'data': {'Data': 'Something'}}],
#   'proof': 119678,
#   'previous_hash': 'fcee7c45bea1b7c4c6f2fb4b78968811e54f32892eaf8767aaff4184d09305fc'},
#  {'index': 5,
#   'timestamp': 1726004297.364224,
#   'transactions': [{'sender': 'Jackson',
#     'recipient': 'Jackson',
#     'data': {'Data': 'Something'}}],
#   'proof': 146502,
#   'previous_hash': '07c33d29bfa0abb25a8c9b7cde46dde9eb3ddf2fae6b4b33c8c8b65aad980c86'},
#  {'index': 6,
#   'timestamp': 1726004297.627328,
#   'transactions': [{'sender': 'Jackson',
#     'recipient': 'Jackson',
#     'data': {'Data': 'Something'}}],
#   'proof': 43538,
#   'previous_hash': 'e6cb8d06e1fd805b268565de4ff5cb04a871f4175a628a0c917afb7412914861'},
#  {'index': 7,
#   'timestamp': 1726004298.064505,
#   'transactions': [{'sender': 'Jackson',
#     'recipient': 'Jackson',
#     'data': {'Data': 'Something'}}],
#   'proof': 85724,
#   'previous_hash': '5ef0a64ada282a422326b740aedea4768f99ce85fbf8f632be63b04a75c95e56'},
#  {'index': 8,
#   'timestamp': 1726004298.4291189,
#   'transactions': [{'sender': 'Jackson',
#     'recipient': 'Jackson',
#     'data': {'Data': 'Something'}}],
#   'proof': 51178,
#   'previous_hash': '39a13c49935d00f56e3bcb08714351ee7db88172c39ddb1ee692296631a27e82'},
#  {'index': 9,
#   'timestamp': 1726004298.904263,
#   'transactions': [{'sender': 'Jackson',
#     'recipient': 'Jackson',
#     'data': {'Data': 'Something'}}],
#   'proof': 71730,
#   'previous_hash': 'acc5c8cd3ff98ad82426fdd3f7eedb3dc471a9533ea9bc85d3c78b8351f7cbd3'},
#  {'index': 10,
#   'timestamp': 1726004299.3375301,
#   'transactions': [{'sender': 'Jackson',
#     'recipient': 'Jackson',
#     'data': {'Data': 'Something'}}],
#   'proof': 55589,
#   'previous_hash': '11c215b2444b63b117ce622e86560506bff467720fce61b04858ba8a802fd8ba'},
#  {'index': 11,
#   'timestamp': 1726004299.736067,
#   'transactions': [{'sender': 'Jackson',
#     'recipient': 'Jackson',
#     'data': {'Data': 'Something'}}],
#   'proof': 35704,
#   'previous_hash': '3af542b01c354ce560fc320655ba2bf3e1272ac0b8044981f2d52faa5801c016'},
#  {'index': 12,
#   'timestamp': 1726004301.801408,
#   'transactions': [{'sender': 'Jackson',
#     'recipient': 'Jackson',
#     'data': {'Data': 'Something'}}],
#   'proof': 57342,
#   'previous_hash': 'a98cdf2ff361110ee6f40c7ac72a73244382628716bf3375e0608c2d2f6e64ca'},
#  {'index': 13,
#   'timestamp': 1726004331.1155999,
#   'transactions': [{'sender': 'Test',
#     'recipient': 'Test',
#     'data': {'Data': 'Some Data Here'}}],
#   'proof': 68975,
#   'previous_hash': 'bb95df0edd6d4a3fec5840414a75bc31b05956ceab4c6208f356f35e23bbf0ef'},
#  {'index': 14,
#   'timestamp': 1726004344.111656,
#   'transactions': [{'sender': 'Test',
#     'recipient': 'Test',
#     'data': {'Data': 'Some Data Here'}}],
#   'proof': 153122,
#   'previous_hash': '760dda6a5e34c389a492b3259c3cb1d2cd6551f2b9f983505893950f1026d1db'},
#  {'index': 15,
#   'timestamp': 1726004344.641976,
#   'transactions': [{'sender': 'Test',
#     'recipient': 'Test',
#     'data': {'Data': 'Some Data Here'}}],
#   'proof': 20760,
#   'previous_hash': '11d78e62bea51d3df3aa6bb91a385ffc09edeae5785ef1c95a207761cf01d116'},
#  {'index': 16,
#   'timestamp': 1726004345.141493,
#   'transactions': [{'sender': 'Test',
#     'recipient': 'Test',
#     'data': {'Data': 'Some Data Here'}}],
#   'proof': 29341,
#   'previous_hash': '93900629ca863e79ef9302b161d589539ecadab7828c3df8a8386f586027d8db'},
#  {'index': 17,
#   'timestamp': 1726004345.592936,
#   'transactions': [{'sender': 'Test',
#     'recipient': 'Test',
#     'data': {'Data': 'Some Data Here'}}],
#   'proof': 15889,
#   'previous_hash': 'c26bef43337d6a574ed3ead289d294eefa8c447d3420227ef44374fe74715593'},
#  {'index': 18,
#   'timestamp': 1726004346.209978,
#   'transactions': [{'sender': 'Test',
#     'recipient': 'Test',
#     'data': {'Data': 'Some Data Here'}}],
#   'proof': 209765,
#   'previous_hash': 'febd3b575003e24d7eaab659c4e6d5c57b6ca66f818c0fe36671ae6a37191855'},
#  {'index': 19,
#   'timestamp': 1726004346.53492,
#   'transactions': [{'sender': 'Test',
#     'recipient': 'Test',
#     'data': {'Data': 'Some Data Here'}}],
#   'proof': 3748,
#   'previous_hash': 'ac685d3a4f6c3ff6ee9c0c076e3d7ba5b45c9c3037c4cfde5f41ff33e7b687f5'},
#  {'index': 20,
#   'timestamp': 1726004347.085098,
#   'transactions': [{'sender': 'Test',
#     'recipient': 'Test',
#     'data': {'Data': 'Some Data Here'}}],
#   'proof': 28807,
#   'previous_hash': 'cfc83100de3aa233cc059bf90f0844ebad80be6923e83f14846dd5a790e47c2a'},
#  {'index': 21,
#   'timestamp': 1726004347.5483232,
#   'transactions': [{'sender': 'Test',
#     'recipient': 'Test',
#     'data': {'Data': 'Some Data Here'}}],
#   'proof': 70832,
#   'previous_hash': '0c8294875dc17751a04bfd0d9ad6f3a4d14e256c31856de7db26bca9f8ef527b'},
#  {'index': 22,
#   'timestamp': 1726004347.996439,
#   'transactions': [{'sender': 'Test',
#     'recipient': 'Test',
#     'data': {'Data': 'Some Data Here'}}],
#   'proof': 47031,
#   'previous_hash': 'f3b5b60c19b89fe7af507f2ac6f2c1626109496e24e7204990e0a7a583beb18a'},
#  {'index': 23,
#   'timestamp': 1726004348.443152,
#   'transactions': [{'sender': 'Test',
#     'recipient': 'Test',
#     'data': {'Data': 'Some Data Here'}}],
#   'proof': 48098,
#   'previous_hash': '8b5df6ae8a996e194c8037f5f238cbfe027e36bd8783e0a38736c86ccf8e7778'},
#  {'index': 24,
#   'timestamp': 1726004348.830003,
#   'transactions': [{'sender': 'Test',
#     'recipient': 'Test',
#     'data': {'Data': 'Some Data Here'}}],
#   'proof': 30743,
#   'previous_hash': 'ebbb8cd21211199d965a4fc688a324357f79044acece84636a6d5c26a3620368'},
#  {'index': 25,
#   'timestamp': 1726004349.2234602,
#   'transactions': [{'sender': 'Test',
#     'recipient': 'Test',
#     'data': {'Data': 'Some Data Here'}}],
#   'proof': 41003,
#   'previous_hash': '8df6085e464553881c9451ac96d362f3cb45c79671f67e197dfc629fc0c42094'},
#  {'index': 26,
#   'timestamp': 1726004349.954637,
#   'transactions': [{'sender': 'Test',
#     'recipient': 'Test',
#     'data': {'Data': 'Some Data Here'}}],
#   'proof': 89991,
#   'previous_hash': 'ea47ba94cf933ace0ef4b9be7ded570c63e0ee937bb3fcc7e45eb9199f117470'}]
